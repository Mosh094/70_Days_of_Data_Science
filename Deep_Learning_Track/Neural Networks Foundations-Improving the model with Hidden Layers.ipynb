# %% [markdown]
# # Multilayer perceptron — the first example of a network

# %% [markdown]
# Defining a Simple Neural Net in Kera

# %%
from __future__ import print_function
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import utils
np.random.seed(1671) #for reproducibility

# %%
#network and training
NB_EPOCH = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 #number of outputs = number of digits
OPTIMIZER = SGD() # normaly without '', but if the model.compile bring the erro below, put ''
#('Could not interpret optimizer identifier:', <class 'tensorflow.python.keras.optimizer_v2.gradient_descent.SGD'>)

N_HIDDEN =128
VALIDATION_SPLIT = 0.2 #How much train is reserved for validation
# Shuffle and split between train and test sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_trainis 60000 rows of 28x28 values  ----> reshaped in 60000 x 784
RESHAPED=784
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
#normalize
#
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train_samples')
print(X_test.shape[0], 'test_samples')
#convert class vectors to binary classmatrices
Y_train = utils.to_categorical (y_train, NB_CLASSES)
Y_test = utils.to_categorical (y_test, NB_CLASSES)
#M_HIDDEN  hidden layers
#outputs = 10
#final stage is softmax
# Out:
# 60000 train_samples
# 10000 test_samples

# %%
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# activation (Activation)      (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# _________________________________________________________________
# activation_2 (Activation)    (None, 10)                0
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=OPTIMIZER, metrics=['accuracy'])

# %%
#training the model
history = model.fit(X_train, Y_train, batch_size = BATCH_SIZE, epochs= NB_EPOCH, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 6s 128us/sample - loss: 1.4779 - accuracy: 0.6317 - val_loss: 0.7450 - val_accuracy: 0.8408
# Epoch 2/20
# 48000/48000 [==============================] - 2s 46us/sample - loss: 0.5902 - accuracy: 0.8528 - val_loss: 0.4541 - val_accuracy: 0.8803
# Epoch 3/20
# 48000/48000 [==============================] - 2s 49us/sample - loss: 0.4358 - accuracy: 0.8815 - val_loss: 0.3768 - val_accuracy: 0.8957
# Epoch 4/20
# 48000/48000 [==============================] - 2s 49us/sample - loss: 0.3777 - accuracy: 0.8943 - val_loss: 0.3394 - val_accuracy: 0.9048
# Epoch 5/20
# 48000/48000 [==============================] - 3s 72us/sample - loss: 0.3437 - accuracy: 0.9027 - val_loss: 0.3147 - val_accuracy: 0.9117
# Epoch 6/20
# 48000/48000 [==============================] - 4s 75us/sample - loss: 0.3197 - accuracy: 0.9100 - val_loss: 0.2952 - val_accuracy: 0.9168
# Epoch 7/20
# 48000/48000 [==============================] - 3s 68us/sample - loss: 0.3009 - accuracy: 0.9149 - val_loss: 0.2798 - val_accuracy: 0.9217
# Epoch 8/20
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.2851 - accuracy: 0.9189 - val_loss: 0.2682 - val_accuracy: 0.9254
# Epoch 9/20
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.2715 - accuracy: 0.9231 - val_loss: 0.2585 - val_accuracy: 0.9261
# Epoch 10/20
# 48000/48000 [==============================] - 3s 56us/sample - loss: 0.2594 - accuracy: 0.9265 - val_loss: 0.2479 - val_accuracy: 0.9296
# Epoch 11/20
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.2487 - accuracy: 0.9296 - val_loss: 0.2396 - val_accuracy: 0.9320
# Epoch 12/20
# 48000/48000 [==============================] - 3s 53us/sample - loss: 0.2390 - accuracy: 0.9322 - val_loss: 0.2313 - val_accuracy: 0.9344
# Epoch 13/20
# 48000/48000 [==============================] - 3s 64us/sample - loss: 0.2302 - accuracy: 0.9346 - val_loss: 0.2235 - val_accuracy: 0.9365
# Epoch 14/20
# 48000/48000 [==============================] - 3s 54us/sample - loss: 0.2219 - accuracy: 0.9373 - val_loss: 0.2163 - val_accuracy: 0.9397
# Epoch 15/20
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.2142 - accuracy: 0.9395 - val_loss: 0.2104 - val_accuracy: 0.9419
# Epoch 16/20
# 48000/48000 [==============================] - 2s 44us/sample - loss: 0.2074 - accuracy: 0.9411 - val_loss: 0.2042 - val_accuracy: 0.9438
# Epoch 17/20
# 48000/48000 [==============================] - 2s 48us/sample - loss: 0.2006 - accuracy: 0.9438 - val_loss: 0.1993 - val_accuracy: 0.9463
# Epoch 18/20
# 48000/48000 [==============================] - 2s 51us/sample - loss: 0.1945 - accuracy: 0.9452 - val_loss: 0.1936 - val_accuracy: 0.9467
# Epoch 19/20
# 48000/48000 [==============================] - 2s 52us/sample - loss: 0.1887 - accuracy: 0.9466 - val_loss: 0.1898 - val_accuracy: 0.9481
# Epoch 20/20
# 48000/48000 [==============================] - 3s 55us/sample - loss: 0.1831 - accuracy: 0.9484 - val_loss: 0.1856 - val_accuracy: 0.9498

# %%
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test Score:", score[0])
print("Test Accurracy:", score[1])
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test Score: 0.18122909616157412
# Test Accurracy: 0.9479
