# %% [markdown]
# # Multilayer perceptron — the first example of a network

# %% [markdown]
# Assignment: Working through the code (deep learning book with keras) in chapter 1 for mnist image, using tensorflow tutorial on eager execution here https://www.tensorflow.org/guide/eager build a simple Neural network architecture of 3 hidden layers with the following values:
# Hidden1 = 300
# Hidden2 = 500
# Hidden3 = 100
# Output neuron = 10
# Optimizer = rmsprop Optimizer
# Loss = Categorical cross entropy.

# %% [markdown]
# Defining a Simple Neural Net in Kera

# %% [markdown]
# # Import Libraries

# %%
from __future__ import print_function
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, Dropout
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import utils
np.random.seed(1671) #for reproducibility

# %%
#network and training
NB_EPOCH = 250
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 #number of outputs = number of digits
OPTIMIZER = RMSprop() # normaly without '', but if the model.compile bring the erro below, put ''
#('Could not interpret optimizer identifier:', <class 'tensorflow.python.keras.optimizer_v2.gradient_descent.SGD'>)

N_HIDDEN1 =300
N_HIDDEN2 = 500
N_HIDDEN3 = 100
VALIDATION_SPLIT = 0.2 #How much train is reserved for validation
DROPOUT = 0.3
# Data Shuffle and split between train and test sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()
#X_train is 60000 rows of 28x28 values  ----> reshaped in 60000 x 784
RESHAPED=784
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
#normalize
#
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train_samples')
print(X_test.shape[0], 'test_samples')
#convert class vectors to binary classmatrices
Y_train = utils.to_categorical (y_train, NB_CLASSES)
Y_test = utils.to_categorical (y_test, NB_CLASSES)
#M_HIDDEN  hidden layers
#outputs = 10
#final stage is softmax
# Out:
# 60000 train_samples
# 10000 test_samples

# %% [markdown]
# # Create Network

# %%
model = Sequential()
model.add(Dense(N_HIDDEN1, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(N_HIDDEN2))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(N_HIDDEN3))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 300)               235500
# _________________________________________________________________
# activation (Activation)      (None, 300)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 300)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               150500
# _________________________________________________________________
# activation_1 (Activation)    (None, 500)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               50100
# ...

# %%
model.compile(loss='categorical_crossentropy', optimizer=OPTIMIZER, metrics=['accuracy'])

# %% [markdown]
# # Training the model

# %%
history = model.fit(X_train, Y_train, batch_size = BATCH_SIZE, epochs= NB_EPOCH, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/250
# 48000/48000 [==============================] - 58s 1ms/sample - loss: 0.3832 - accuracy: 0.8834 - val_loss: 0.1499 - val_accuracy: 0.9548
# Epoch 2/250
# 48000/48000 [==============================] - 19s 404us/sample - loss: 0.1703 - accuracy: 0.9511 - val_loss: 0.1093 - val_accuracy: 0.9680
# Epoch 3/250
# 48000/48000 [==============================] - 26s 548us/sample - loss: 0.1290 - accuracy: 0.9635 - val_loss: 0.1121 - val_accuracy: 0.9679
# Epoch 4/250
# 48000/48000 [==============================] - 18s 374us/sample - loss: 0.1082 - accuracy: 0.9689 - val_loss: 0.0974 - val_accuracy: 0.9753
# Epoch 5/250
# 48000/48000 [==============================] - 25s 520us/sample - loss: 0.0948 - accuracy: 0.9737 - val_loss: 0.0974 - val_accuracy: 0.9757
# Epoch 6/250
# 48000/48000 [==============================] - 26s 549us/sample - loss: 0.0884 - accuracy: 0.9750 - val_loss: 0.0968 - val_accuracy: 0.9777
# Epoch 7/250
# ...

# %% [markdown]
# # Test Model

# %%
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test Score:", score[0])
print("Test Accurracy:", score[1])
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...
